# %%
import numpy as np
import matplotlib.pyplot as plt

# Параметри мережі
U_rms = 220       # Действующее напряжение, В
f = 50            # Частота, Гц
omega = 2 * np.pi * f
U_m = U_rms * np.sqrt(2)  # Амплитудное напряжение (~311.13 В)

# Всі часу (3 періоди: T = 1/50 = 0.02 с = 20 мс, всього 0.06 с)
t = np.linspace(0, 0.06, 1000)
u = U_m * np.sin(omega * t)

# Побудова графіка
plt.figure(figsize=(10, 5))
plt.plot(t * 1000, u, color='tab:blue', linewidth=2, label=f'$u(t) = {U_m:.1f} \\sin(100\\pi t)$')

# Оформлення та позначення
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.axhline(U_m, color='red', linestyle=':', label=f'Амплітуда $U_m \\approx {U_m:.1f}$ В')
plt.axhline(-U_m, color='red', linestyle=':')
plt.axhline(U_rms, color='orange', linestyle='--', label=f'Діюче $U_{{rms}} = {U_rms}$ В')

plt.title('Синусоїдальна напруга електромережі (220 В, 50 Гц)', fontsize=13)
plt.xlabel('Час, мс', fontsize=11)
plt.ylabel('Напруга, В', fontsize=11)
plt.grid(True, linestyle=':', alpha=0.7)
plt.legend(loc='upper right')
plt.xlim(0, 60)

plt.show()
